# %%
import pandas as pd
import os

# %%
def compuerta_AND():
      A = [1,1,0,0]
      B = [1,0,1,0]
      AandB = [None]*4
      for i in range(4):
            AandB[i] = A[i] and B[i]
      
      print("Compuerta Lógica AND")
      tablaAND = {'A': A, 'B': B, 'A and B': AandB}
      tablaAND_df = pd.DataFrame(tablaAND)
      print(tablaAND_df)

compuerta_AND()
# Out:
# Compuerta Lógica AND
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\UPIICSA\Primer Semestre\Lógica de Progrmación\Juankas\main.ipynb Cell 2' in <module>
#      <a href='vscode-notebook-cell:/d%3A/UPIICSA/Primer%20Semestre/L%C3%B3gica%20de%20Progrmaci%C3%B3n/Juankas/main.ipynb#ch0000001?line=9'>10</a>       tablaAND_df = pd.DataFrame(tablaAND)
#      <a href='vscode-notebook-cell:/d%3A/UPIICSA/Primer%20Semestre/L%C3%B3gica%20de%20Progrmaci%C3%B3n/Juankas/main.ipynb#ch0000001?line=10'>11</a>       print(tablaAND_df)
# ---> <a href='vscode-notebook-cell:/d%3A/UPIICSA/Primer%20Semestre/L%C3%B3gica%20de%20Progrmaci%C3%B3n/Juankas/main.ipynb#ch0000001?line=12'>13</a> compuerta_AND()
#
# d:\UPIICSA\Primer Semestre\Lógica de Progrmación\Juankas\main.ipynb Cell 2' in compuerta_AND()
#       <a href='vscode-notebook-cell:/d%3A/UPIICSA/Primer%20Semestre/L%C3%B3gica%20de%20Progrmaci%C3%B3n/Juankas/main.ipynb#ch0000001?line=7'>8</a> print("Compuerta Lógica AND")
#       <a href='vscode-notebook-cell:/d%3A/UPIICSA/Primer%20Semestre/L%C3%B3gica%20de%20Progrmaci%C3%B3n/Juankas/main.ipynb#ch0000001?line=8'>9</a> tablaAND = {'A': A, 'B': B, 'A and B': AandB}
# ---> <a href='vscode-notebook-cell:/d%3A/UPIICSA/Primer%20Semestre/L%C3%B3gica%20de%20Progrmaci%C3%B3n/Juankas/main.ipynb#ch0000001?line=9'>10</a> tablaAND_df = pd.DataFrame(tablaAND)
#      <a href='vscode-notebook-cell:/d%3A/UPIICSA/Primer%20Semestre/L%C3%B3gica%20de%20Progrmaci%C3%B3n/Juankas/main.ipynb#ch0000001?line=10'>11</a> print(tablaAND_df)
#
# NameError: name 'pd' is not defined

# %%
#Compuerta OR
def compuerta_OR():
      A = [1,1,0,0]
      B = [1,0,1,0]
      AorB = [None]*4
      for i in range(4):
            AorB[i] = A[i] or B[i]
      
      print("Compuerta Lógica OR")
      tablaAND = {'A': A, 'B': B, 'A and B': AorB}
      tablaAND_df = pd.DataFrame(tablaAND)
      print(tablaAND_df)

compuerta_OR()
# Out:
# Compuerta Lógica OR
#    A  B  A and B
# 0  1  1        1
# 1  1  0        1
# 2  0  1        1
# 3  0  0        0

# %%
#Compuerta XOR
def compuerta_XOR(): 
      A = [1,1,0,0]
      B = [1,0,1,0]
      AxorB = [None]*4
      for i in range(4):
            AxorB[i] = not((A[i]==0 and B[i]==0) or (A[i]==1 and B[i]==1))
            if AxorB[i]==True:
                  AxorB.append(1)
            else:
                  AxorB.append(0)
      del(AxorB[0:4])
      print(AxorB)
      print("Compuerta Lógica XOR")
      tablaAND = {'A': A, 'B': B, 'A and B': AxorB}
      tablaAND_df = pd.DataFrame(tablaAND)
      print(tablaAND_df)

compuerta_XOR()
# Out:
# [0, 1, 1, 0]
# Compuerta Lógica XOR
#    A  B  A and B
# 0  1  1        0
# 1  1  0        1
# 2  0  1        1
# 3  0  0        0

# %%
#Compuerta NAND
def compuerta_NAND():
      A = [1,1,0,0]
      B = [1,0,1,0]
      AnandB = [None]*4
      for i in range(4):
            AnandB[i] = not( A[i] and B[i])
            
            if AnandB[i]==True:
                  AnandB.append(1)
            else:
                  AnandB.append(0)
                  
      del(AnandB[0:4])
      print("Compuerta Lógica NAND")
      tablaNAND = {'A': A, 'B': B, 'A and B': AnandB}
      tablaNAND_df = pd.DataFrame(tablaNAND)
      print(tablaNAND_df)

compuerta_NAND()
# Out:
# Compuerta Lógica NAND
#    A  B  A and B
# 0  1  1        0
# 1  1  0        1
# 2  0  1        1
# 3  0  0        1

# %%
def compuerta_NOR():
    
      A = [1,1,0,0]
      B = [1,0,1,0]
      AnorB = [None]*4
      for i in range(4):
            AnorB[i] = not(A[i] or B[i])
            if AnorB[i]==True:
                  AnorB.append(1)
            else:
                  AnorB.append(0)
      del(AnorB[0:4])
      print("Compuerta Lógica NOR")
      tablaNOR = {'A': A, 'B': B, 'A and B': AnorB}
      tablaNOR_df = pd.DataFrame(tablaNOR)
      print(tablaNOR_df)

compuerta_NOR()
# Out:
# Compuerta Lógica NOR
#    A  B  A and B
# 0  1  1        0
# 1  1  0        0
# 2  0  1        0
# 3  0  0        1

# %%
#Compuerta XNOR
def compuerta_XNOR(): 
      A = [1,1,0,0]
      B = [1,0,1,0]
      AxnorB = [None]*4
      for i in range(4):
            AxnorB[i] = not(not((A[i]==0 and B[i]==0) or (A[i]==1 and B[i]==1)))
            if AxnorB[i]==True:
                  AxnorB.append(1)
            else:
                  AxnorB.append(0)
      del(AxnorB[0:4])
      print(AxnorB)
      print("Compuerta Lógica XOR")
      tablaXNOR = {'A': A, 'B': B, 'A and B': AxnorB}
      tablaXNOR_df = pd.DataFrame(tablaXNOR)
      print(tablaXNOR_df)

compuerta_XNOR()
# Out:
# [1, 0, 0, 1]
# Compuerta Lógica XOR
#    A  B  A and B
# 0  1  1        1
# 1  1  0        0
# 2  0  1        0
# 3  0  0        1

# %%
rep = 1
while rep==1:
    print("PROYECTO: COMPUERTAS LÓGICAS\nEQUIPO: N \nCOMPUESTO POR:\n->\n->\n")
    print("Seleccione una compuerta\n1)Compuerta AND\n2)Compuerta OR\n3)Compuerta XOR\n4)Compuerta\n5)Compuerta\n6)Compuerta\n")
    
    op = int(input("ingrese un numero"))
    
    if op == 1:
        compuerta_AND()
        os.system ("cls")
    
    elif op == 2:
        compuerta_OR()
        os.system ("cls")
    
    elif op == 3:
        compuerta_XOR()
        os.system ("cls")

    elif op == 4:
        compuerta_NAND()
        os.system ("cls")

    elif op == 5:
        compuerta_NOR()
        os.system ("cls")

    elif op == 6:
        compuerta_XNOR()
        os.system ("cls")
    
    else:
        print("opcion invalida")
# Out:
# PROYECTO: COMPUERTAS LÓGICAS
# EQUIPO: N
# COMPUESTO POR:
# ->
# ->
#
# Seleccione una compuerta
# 1)Compuerta AND
# 2)Compuerta OR
# 3)Compuerta XOR
# 4)Compuerta
# 5)Compuerta
# 6)Compuerta
#
# Compuerta Lógica AND
#    A  B  A and B
# 0  1  1        1
# 1  1  0        0
# 2  0  1        0
# 3  0  0        0
# PROYECTO: COMPUERTAS LÓGICAS
# EQUIPO: N
# COMPUESTO POR:
# ->
# ->
#
# Seleccione una compuerta
# 1)Compuerta AND
# 2)Compuerta OR
# 3)Compuerta XOR
# 4)Compuerta
# 5)Compuerta
# 6)Compuerta
#
# Compuerta Lógica AND
#    A  B  A and B
# 0  1  1        1
# 1  1  0        0
# 2  0  1        0
# 3  0  0        0
# PROYECTO: COMPUERTAS LÓGICAS
# EQUIPO: N
# COMPUESTO POR:
# ->
# ->
#
# Seleccione una compuerta
# 1)Compuerta AND
# 2)Compuerta OR
# 3)Compuerta XOR
# 4)Compuerta
# 5)Compuerta
# 6)Compuerta
#
# Compuerta Lógica OR
#    A  B  A and B
# 0  1  1        1
# 1  1  0        1
# 2  0  1        1
# 3  0  0        0
# PROYECTO: COMPUERTAS LÓGICAS
# EQUIPO: N
# COMPUESTO POR:
# ->
# ->
#
# Seleccione una compuerta
# 1)Compuerta AND
# 2)Compuerta OR
# 3)Compuerta XOR
# 4)Compuerta
# 5)Compuerta
# 6)Compuerta
#
# Compuerta Lógica OR
#    A  B  A and B
# 0  1  1        1
# 1  1  0        1
# 2  0  1        1
# 3  0  0        0
# PROYECTO: COMPUERTAS LÓGICAS
# EQUIPO: N
# COMPUESTO POR:
# ->
# ->
#
# Seleccione una compuerta
# 1)Compuerta AND
# 2)Compuerta OR
# 3)Compuerta XOR
# 4)Compuerta
# 5)Compuerta
# 6)Compuerta
#
# [0, 1, 1, 0]
# Compuerta Lógica XOR
#    A  B  A and B
# 0  1  1        0
# 1  1  0        1
# 2  0  1        1
# 3  0  0        0
# PROYECTO: COMPUERTAS LÓGICAS
# EQUIPO: N
# COMPUESTO POR:
# ->
# ->
#
# Seleccione una compuerta
# 1)Compuerta AND
# 2)Compuerta OR
# 3)Compuerta XOR
# 4)Compuerta
# 5)Compuerta
# 6)Compuerta
#
# Compuerta Lógica NAND
#    A  B  A and B
# 0  1  1        0
# 1  1  0        1
# 2  0  1        1
# 3  0  0        1
# PROYECTO: COMPUERTAS LÓGICAS
# EQUIPO: N
# COMPUESTO POR:
# ->
# ->
#
# Seleccione una compuerta
# 1)Compuerta AND
# 2)Compuerta OR
# 3)Compuerta XOR
# 4)Compuerta
# 5)Compuerta
# 6)Compuerta
#
# Compuerta Lógica NAND
#    A  B  A and B
# 0  1  1        0
# 1  1  0        1
# 2  0  1        1
# 3  0  0        1
# PROYECTO: COMPUERTAS LÓGICAS
# EQUIPO: N
# COMPUESTO POR:
# ->
# ->
#
# Seleccione una compuerta
# 1)Compuerta AND
# 2)Compuerta OR
# 3)Compuerta XOR
# 4)Compuerta
# 5)Compuerta
# 6)Compuerta
#
# Compuerta Lógica NOR
#    A  B  A and B
# 0  1  1        0
# 1  1  0        0
# 2  0  1        0
# 3  0  0        1
# PROYECTO: COMPUERTAS LÓGICAS
# EQUIPO: N
# COMPUESTO POR:
# ->
# ->
#
# Seleccione una compuerta
# 1)Compuerta AND
# 2)Compuerta OR
# 3)Compuerta XOR
# 4)Compuerta
# 5)Compuerta
# 6)Compuerta
#
# [1, 0, 0, 1]
# Compuerta Lógica XOR
#    A  B  A and B
# 0  1  1        1
# 1  1  0        0
# 2  0  1        0
# 3  0  0        1
# PROYECTO: COMPUERTAS LÓGICAS
# EQUIPO: N
# COMPUESTO POR:
# ->
# ->
#
# Seleccione una compuerta
# 1)Compuerta AND
# 2)Compuerta OR
# 3)Compuerta XOR
# 4)Compuerta
# 5)Compuerta
# 6)Compuerta
#
# [1, 0, 0, 1]
# Compuerta Lógica XOR
#    A  B  A and B
# 0  1  1        1
# 1  1  0        0
# 2  0  1        0
# 3  0  0        1
# PROYECTO: COMPUERTAS LÓGICAS
# EQUIPO: N
# COMPUESTO POR:
# ->
# ->
#
# Seleccione una compuerta
# 1)Compuerta AND
# 2)Compuerta OR
# 3)Compuerta XOR
# 4)Compuerta
# 5)Compuerta
# 6)Compuerta
#
# Compuerta Lógica NOR
#    A  B  A and B
# 0  1  1        0
# 1  1  0        0
# 2  0  1        0
# 3  0  0        1
# PROYECTO: COMPUERTAS LÓGICAS
# EQUIPO: N
# COMPUESTO POR:
# ->
# ->
#
# Seleccione una compuerta
# 1)Compuerta AND
# 2)Compuerta OR
# 3)Compuerta XOR
# 4)Compuerta
# 5)Compuerta
# 6)Compuerta
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\UPIICSA\Primer Semestre\Lógica de Progrmación\Juankas\main.ipynb Cell 8' in <module>
#       <a href='vscode-notebook-cell:/d%3A/UPIICSA/Primer%20Semestre/L%C3%B3gica%20de%20Progrmaci%C3%B3n/Juankas/main.ipynb#ch0000007?line=2'>3</a> print("PROYECTO: COMPUERTAS LÓGICAS\nEQUIPO: N \nCOMPUESTO POR:\n->\n->\n")
#       <a href='vscode-notebook-cell:/d%3A/UPIICSA/Primer%20Semestre/L%C3%B3gica%20de%20Progrmaci%C3%B3n/Juankas/main.ipynb#ch0000007?line=3'>4</a> print("Seleccione una compuerta\n1)Compuerta AND\n2)Compuerta OR\n3)Compuerta XOR\n4)Compuerta\n5)Compuerta\n6)Compuerta\n")
# ----> <a href='vscode-notebook-cell:/d%3A/UPIICSA/Primer%20Semestre/L%C3%B3gica%20de%20Progrmaci%C3%B3n/Juankas/main.ipynb#ch0000007?line=5'>6</a> op = int(input("ingrese un numero"))
#       <a href='vscode-notebook-cell:/d%3A/UPIICSA/Primer%20Semestre/L%C3%B3gica%20de%20Progrmaci%C3%B3n/Juankas/main.ipynb#ch0000007?line=7'>8</a> if op == 1:
#       <a href='vscode-notebook-cell:/d%3A/UPIICSA/Primer%20Semestre/L%C3%B3gica%20de%20Progrmaci%C3%B3n/Juankas/main.ipynb#ch0000007?line=8'>9</a>     compuerta_AND()
#
# ValueError: invalid literal for int() with base 10: ''
